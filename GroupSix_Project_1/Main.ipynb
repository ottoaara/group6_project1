# %%
#main data file and import script for class group 6  project 1
# Author AO ottoaara@gmail.com. 952.693.1378 
# 5.5.23
# data source mpls open data https://opendata.minneapolismn.gov/datasets/cityoflakes::crime-data/explore?location=19.216823%2C-46.664577%2C4.00
# CSV option under Crime Data Header
import pandas as pd
import csv
import json
import matplotlib as pyplot
import geopandas as gpd
from shapely.geometry import Point, Polygon
#crime_data_main  = full data set (75 Megs so seperated out into groups for ease of dev)
#ran_crime_data_df is a light 1000 rows of data randomly choosen from crime_data_man to work with
#crime_data_2019 = data for 2019 
#crime_data_2020 ...
#crime_data_2021 ...
#crime_data_2022...
##crime_data_2023 = data for 2023 
filename = "Crime_Data.csv"
csvdatapath = "Data/" + filename

# %%
# download local from repo to desktop (clone to your desktop)
#this reads the csv file 
crime_data_main = pd.read_csv(csvdatapath)

# %%
#columns listed for ease of co-development use. 
crime_data_main.columns
# Out:
# Index(['X', 'Y', 'Type', 'Case_Number', 'Case_NumberAlt', 'Reported_Date',
#        'Occurred_Date', 'NIBRS_Crime_Against', 'NIBRS_Group', 'NIBRS_Code',
#        'Offense_Category', 'Offense', 'Problem_Initial', 'Problem_Final',
#        'Address', 'Precinct', 'Neighborhood', 'Ward', 'Latitude', 'Longitude',
#        'wgsXAnon', 'wgsYAnon', 'Crime_Count', 'OBJECTID'],
#       dtype='object')

# %%
#checkign data types 
crime_data_main.dtypes
# Out:
# X                      float64
# Y                      float64
# Type                    object
# Case_Number             object
# Case_NumberAlt          object
# Reported_Date           object
# Occurred_Date           object
# NIBRS_Crime_Against     object
# NIBRS_Group             object
# NIBRS_Code              object
# Offense_Category        object
# Offense                 object
# Problem_Initial         object
# Problem_Final           object
# Address                 object
# Precinct               float64
# Neighborhood            object
# Ward                   float64
# Latitude               float64
# Longitude              float64
# wgsXAnon               float64
# wgsYAnon               float64
# Crime_Count              int64
# OBJECTID                 int64
# dtype: object

# %%
#get count of one column to prep for null value check 
crime_data_main["X"].count()
# Out:
# 226120

# %%
# Remove rows containing all null values- cleaning data set
crime_data_clean = crime_data_main.dropna(how='any')

# %%
# removing rows with null values.  
crime_data_clean["X"].count()
# Out:
# 151701

# %%
# checking values of crime category to reduce our data set down further to violent crimes 
crime_data_clean["Offense_Category"].unique()
# Out:
# array(['Subset of NIBRS Assault Offenses', 'Assault Offenses ',
#        'Larceny/Theft Offenses ', 'Sex Offenses ',
#        'Drug/Narcotic Offenses ', 'Robbery ', 'Fraud Offenses ',
#        'Burglary/Breaking & Entering ', 'Motor Vehicle Theft ',
#        'Stolen Property Offenses ', 'Weapon Law Violations ',
#        'Counterfeiting/Forgery ', 'Extortion/Blackmail ',
#        'Kidnapping/Abduction ', 'Embezzlement ',
#        'Subset of NIBRS Robbery', 'Pornography/Obscene Material ',
#        'Prostitution Offenses ', 'Arson ', 'Homicide Offenses ',
#        'Destruction/Damage/Vandalism of Property ', 'Animal Cruelty ',
#        'Human Trafficking ', 'Bribery ', 'Gambling Offenses ',
#        'Gunshot Wound Victims', 'Shots Fired Calls'], dtype=object)

# %%
# reducing the data sets to only have violent crimes in them.  Note Included motor vehicle theft due to the
# high volumme of car-jackings occuring in mpls. 

crime_categories = [
    'Subset of NIBRS Assault Offenses',
    'Assault Offenses',
    'Larceny/Theft Offenses',
    'Sex Offenses',
    'Robbery',
    'Burglary/Breaking & Entering',
    'Motor Vehicle Theft',
    'Weapon Law Violations',
    'Kidnapping/Abduction',
    'Homicide Offenses',
    'Human Trafficking',
    'Gunshot Wound Victims',
    'Shots Fired Calls'
]

crime_data_clean = crime_data_clean[crime_data_clean['Offense_Category'].isin(crime_categories)]

# %%
#changing Occured_Date filed to data/time from object
crime_data_clean['Occurred_Date'] = pd.to_datetime(crime_data_clean['Occurred_Date'])

# %%
#checking to make sure date/time conv worked 
crime_data_clean.dtypes
# Out:
# X                                  float64
# Y                                  float64
# Type                                object
# Case_Number                         object
# Case_NumberAlt                      object
# Reported_Date                       object
# Occurred_Date          datetime64[ns, UTC]
# NIBRS_Crime_Against                 object
# NIBRS_Group                         object
# NIBRS_Code                          object
# Offense_Category                    object
# Offense                             object
# Problem_Initial                     object
# Problem_Final                       object
# Address                             object
# Precinct                           float64
# Neighborhood                        object
# Ward                               float64
# Latitude                           float64
# Longitude                          float64
# wgsXAnon                           float64
# wgsYAnon                           float64
# Crime_Count                          int64
# OBJECTID                             int64
# dtype: object

# %%
#building random data set 
n_samples = min(1000, len(crime_data_clean))
ran_crime_data_df = crime_data_clean.sample(n=n_samples, random_state=42)

# %%
#building year data sets
crime_data_2019 = crime_data_clean[crime_data_clean['Occurred_Date'].dt.year == 2019]
crime_data_2020 = crime_data_clean[crime_data_clean['Occurred_Date'].dt.year == 2020]
crime_data_2021 = crime_data_clean[crime_data_clean['Occurred_Date'].dt.year == 2021]
crime_data_2022 = crime_data_clean[crime_data_clean['Occurred_Date'].dt.year == 2022]
crime_data_2023 = crime_data_clean[crime_data_clean['Occurred_Date'].dt.year == 2023]

# %%
# grouping with smaller data set to look at where the crimes are happening - counting number of offenses 
#grouped_data = ran_crime_data_df.groupby(['Neighborhood', 'Address']).size().reset_index(name='Offense_Count')
grouped_data = ran_crime_data_df.groupby(['Neighborhood', 'Address', 'Offense_Category']).size().reset_index(name='Offense_Count')

# %%
#sorting grouped data to show the worst parts of town ie sorting by places more than one offense occurred
sorted_grouped_data = grouped_data.sort_values(by='Offense_Count', ascending=False)

# %%
# viewing sorted data frame. 
sorted_grouped_data
# Out:
#                          Neighborhood               Address  \
# 205                         Hawthorne  0021XX ALDRICH AVE N
# 350                   Lowry Hill East   0028XX DUPONT AVE S
# 204                         Hawthorne  0021XX ALDRICH AVE N
# 251                            Jordan     0014XX 29TH AVE N
# 526  Steven's Square - Loring Heights      0018XX 1ST AVE S
# ..                                ...                   ...
# 239                           Holland   0007XX LOWRY AVE NE
# 238                           Holland    0006XX 26TH AVE NE
# 237                           Holland    0006XX 26TH AVE NE
# 236                           Holland    0006XX 19TH AVE NE
# 332                       Loring Park   0014XX NICOLLET AVE
#
#                      Offense_Category  Offense_Count
# 205                 Shots Fired Calls             14
# 350  Subset of NIBRS Assault Offenses             11
# 204             Gunshot Wound Victims              9
# 251  Subset of NIBRS Assault Offenses              8
# 526  Subset of NIBRS Assault Offenses              8
# ..                                ...            ...
# 239             Gunshot Wound Victims              1
# 238  Subset of NIBRS Assault Offenses              1
# 237             Gunshot Wound Victims              1
# 236                 Shots Fired Calls              1
# 332                 Shots Fired Calls              1
#
# [665 rows x 4 columns]

# %%
# adding in date time to support further analysis to check correlation between time and offense
grouped_data_bydate = ran_crime_data_df.groupby(['Neighborhood', 'Address', 'Offense_Category', 'Occurred_Date']).size().reset_index(name='Offense_Count')

# %%
grouped_data_bydate
# Out:
#      Neighborhood               Address                  Offense_Category  \
# 0        Armatage      0027XX 59TH ST W  Subset of NIBRS Assault Offenses
# 1    Audubon Park    0010XX 28TH AVE NE                 Shots Fired Calls
# 2    Audubon Park    0011XX 26TH AVE NE  Subset of NIBRS Assault Offenses
# 3        Bancroft      0007XX 40TH ST E                 Shots Fired Calls
# 4        Bancroft      0011XX 39TH ST E  Subset of NIBRS Assault Offenses
# ..            ...                   ...                               ...
# 995        Windom  0058XX LYNDALE AVE S                 Shots Fired Calls
# 996   Windom Park  0010XX 18 1/2 AVE NE                 Shots Fired Calls
# 997   Windom Park  0010XX 18 1/2 AVE NE  Subset of NIBRS Assault Offenses
# 998   Windom Park    0020XX 19TH AVE NE  Subset of NIBRS Assault Offenses
# 999   Windom Park    0020XX 19TH AVE NE  Subset of NIBRS Assault Offenses
#
#                 Occurred_Date  Offense_Count
# 0   2020-05-19 18:20:00+00:00              1
# 1   2021-08-28 23:50:36+00:00              1
# 2   2020-02-22 21:22:00+00:00              1
# 3   2021-04-20 22:46:23+00:00              1
# 4   2020-01-31 18:48:00+00:00              1
# ..                        ...            ...
# 995 2020-06-18 04:05:59+00:00              1
# 996 2020-01-07 17:58:33+00:00              1
# 997 2021-02-06 10:00:00+00:00              1
# 998 2020-11-23 14:21:00+00:00              1
# 999 2022-02-09 14:28:00+00:00              1
#
# [1000 rows x 5 columns]

# %%
# viewing sorted data frame. 
sorted_grouped_data = grouped_data_bydate.sort_values(by='Offense_Count', ascending=False)
sorted_grouped_data
# Out:
#                     Neighborhood               Address  \
# 0                       Armatage      0027XX 59TH ST W
# 671                     Northrop      0010XX 44TH ST E
# 658                 Near - North  0021XX ALDRICH AVE N
# 659  Nicollet Island - East Bank     0001XX MAIN ST NE
# 660  Nicollet Island - East Bank     0001XX MERRIAM ST
# ..                           ...                   ...
# 338                    Hawthorne       0025XX 4TH ST N
# 339                    Hawthorne  0025XX ALDRICH AVE N
# 340                    Hawthorne   0026XX DUPONT AVE N
# 341                    Hawthorne       0027XX 3RD ST N
# 999                  Windom Park    0020XX 19TH AVE NE
#
#                      Offense_Category             Occurred_Date  Offense_Count
# 0    Subset of NIBRS Assault Offenses 2020-05-19 18:20:00+00:00              1
# 671  Subset of NIBRS Assault Offenses 2021-01-24 17:44:00+00:00              1
# 658                 Shots Fired Calls 2021-04-08 14:30:48+00:00              1
# 659  Subset of NIBRS Assault Offenses 2020-07-07 07:38:00+00:00              1
# 660  Subset of NIBRS Assault Offenses 2023-01-16 21:53:00+00:00              1
# ..                                ...                       ...            ...
# 338                 Shots Fired Calls 2021-06-06 01:15:06+00:00              1
# 339                 Shots Fired Calls 2020-10-16 03:43:54+00:00              1
# 340                 Shots Fired Calls 2021-05-08 03:59:56+00:00              1
# 341                 Shots Fired Calls 2020-03-23 13:21:35+00:00              1
# 999  Subset of NIBRS Assault Offenses 2022-02-09 14:28:00+00:00              1
#
# [1000 rows x 5 columns]

# %%
# adding long and lat. for analysis by location 
crime_data_byLongLat = grouped_data_bydate.merge(
    crime_data_clean[['Neighborhood', 'Address', 'Latitude', 'Longitude']],
    on=['Neighborhood', 'Address'],
    how='left')

# %%
crime_data_bylonglat
# Out:
#                X          Y                      Type Case_Number  \
# 0     -93.249966  44.970026  Additional Crime Metrics   23-086158
# 1     -93.249966  44.970026  Additional Crime Metrics   23-086158
# 2     -93.249966  44.970026  Additional Crime Metrics   23-086158
# 3     -93.249966  44.970026  Additional Crime Metrics   23-086158
# 4     -93.249966  44.970026  Additional Crime Metrics   23-086158
# ...          ...        ...                       ...         ...
# 26322 -93.315244  45.007836     Gunshot Wound Victims   19-262832
# 26323 -93.315244  45.007836     Gunshot Wound Victims   19-262832
# 26324 -93.315244  45.007836     Gunshot Wound Victims   19-262832
# 26325 -93.315244  45.007836     Gunshot Wound Victims   19-262832
# 26326 -93.315244  45.007836     Gunshot Wound Victims   19-262832
#
#       Case_NumberAlt           Reported_Date             Occurred_Date  \
# 0        MP202386158  2023/04/09 15:46:00+00 2023-04-09 14:50:00+00:00
# 1        MP202386158  2023/04/09 15:46:00+00 2023-04-09 14:50:00+00:00
# 2        MP202386158  2023/04/09 15:46:00+00 2023-04-09 14:50:00+00:00
# 3        MP202386158  2023/04/09 15:46:00+00 2023-04-09 14:50:00+00:00
# 4        MP202386158  2023/04/09 15:46:00+00 2023-04-09 14:50:00+00:00
# ...              ...                     ...                       ...
# 26322   MP2019262832  2019/08/31 19:47:00+00 2019-08-31 18:28:00+00:00
# 26323   MP2019262832  2019/08/31 19:47:00+00 2019-08-31 18:28:00+00:00
# 26324   MP2019262832  2019/08/31 19:47:00+00 2019-08-31 18:28:00+00:00
# 26325   MP2019262832  2019/08/31 19:47:00+00 2019-08-31 18:28:00+00:00
# 26326   MP2019262832  2019/08/31 19:47:00+00 2019-08-31 18:28:00+00:00
#
#       NIBRS_Crime_Against     NIBRS_Group      NIBRS_Code  ...  \
# 0          Non NIBRS Data  Non NIBRS Data  Non NIBRS Data  ...
# 1          Non NIBRS Data  Non NIBRS Data  Non NIBRS Data  ...
# 2          Non NIBRS Data  Non NIBRS Data  Non NIBRS Data  ...
# 3          Non NIBRS Data  Non NIBRS Data  Non NIBRS Data  ...
# 4          Non NIBRS Data  Non NIBRS Data  Non NIBRS Data  ...
# ...                   ...             ...             ...  ...
# 26322      Non NIBRS Data  Non NIBRS Data  Non NIBRS Data  ...
# 26323      Non NIBRS Data  Non NIBRS Data  Non NIBRS Data  ...
# 26324      Non NIBRS Data  Non NIBRS Data  Non NIBRS Data  ...
# 26325      Non NIBRS Data  Non NIBRS Data  Non NIBRS Data  ...
# 26326      Non NIBRS Data  Non NIBRS Data  Non NIBRS Data  ...
#
#           Neighborhood Ward Latitude_x Longitude_x      wgsXAnon  \
# 0      Cedar Riverside  6.0   44.97003   -93.24997 -1.038054e+07
# 1      Cedar Riverside  6.0   44.97003   -93.24997 -1.038054e+07
# 2      Cedar Riverside  6.0   44.97003   -93.24997 -1.038054e+07
# 3      Cedar Riverside  6.0   44.97003   -93.24997 -1.038054e+07
# 4      Cedar Riverside  6.0   44.97003   -93.24997 -1.038054e+07
# ...                ...  ...        ...         ...           ...
# 26322           Jordan  4.0   45.00784   -93.31524 -1.038781e+07
# 26323           Jordan  4.0   45.00784   -93.31524 -1.038781e+07
# 26324           Jordan  4.0   45.00784   -93.31524 -1.038781e+07
# 26325           Jordan  4.0   45.00784   -93.31524 -1.038781e+07
# 26326           Jordan  4.0   45.00784   -93.31524 -1.038781e+07
#
#            wgsYAnon Crime_Count  OBJECTID  Latitude_y  Longitude_y
# 0      5.616804e+06           3      6093    44.97003    -93.24997
# 1      5.616804e+06           3      6093    44.97003    -93.24997
# 2      5.616804e+06           3      6093    44.97003    -93.24997
# 3      5.616804e+06           3      6093    44.97003    -93.24997
# 4      5.616804e+06           3      6093    44.97003    -93.24997
# ...             ...         ...       ...         ...          ...
# 26322  5.622755e+06           1    215643    45.00784    -93.31524
# 26323  5.622755e+06           1    215643    45.00784    -93.31524
# 26324  5.622755e+06           1    215643    45.00784    -93.31524
# 26325  5.622755e+06           1    215643    45.00784    -93.31524
# 26326  5.622755e+06           1    215643    45.00784    -93.31524
#
# [26327 rows x 26 columns]
